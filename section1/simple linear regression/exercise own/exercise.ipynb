# %% [markdown]
# ##  the  main aim of this exercise is to predict the brain size given the  head size

# %% [markdown]
# #### load the required modules

# %%
import numpy as np
import seaborn
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd 
seaborn.set()

# %% [markdown]
# ### loading the data

# %%
data =pd.read_csv('headbrain11.csv')

# %%
data
# Out:
#      Head Size(cm^3)   Brain Weight(grams)
# 0                4512                 1530
# 1                3738                 1297
# 2                4261                 1335
# 3                3777                 1282
# 4                4177                 1590
# ..                ...                  ...
# 232              3214                 1110
# 233              3394                 1215
# 234              3233                 1104
# 235              3352                 1170
# 236              3391                 1120
#
# [237 rows x 2 columns]

# %%
data.describe()
# Out:
#        Head Size(cm^3)   Brain Weight(grams)
# count        237.000000           237.000000
# mean        3633.991561          1282.873418
# std          365.261422           120.340446
# min         2720.000000           955.000000
# 25%         3389.000000          1207.000000
# 50%         3614.000000          1280.000000
# 75%         3876.000000          1350.000000
# max         4747.000000          1635.000000

# %% [markdown]
# ###  exploring the data

# %%
y=data['Brain Weight(grams)']
x1=data['Head Size(cm^3) ']

# %%
plt.scatter(x1,y)
plt.xlabel('Head Size(cm^3) ', fontsize=15)
plt.ylabel('Brain Weight(grams)', fontsize=15)
plt.show()

# %% [markdown]
# ### The regression itself

# %%
x=sm.add_constant(x1)
results=sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Brain Weight(grams)   R-squared:                       0.639
# Model:                             OLS   Adj. R-squared:                  0.638
# Method:                  Least Squares   F-statistic:                     416.5
# Date:                 Wed, 13 Nov 2024   Prob (F-statistic):           5.96e-54
# Time:                         10:41:56   Log-Likelihood:                -1350.3
# No. Observations:                  237   AIC:                             2705.
# Df Residuals:                      235   BIC:                             2711.
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
plt.scatter(x1,y)
yhat=0.2634	*x1 +325.5734	
fig=plt.plot(x1, yhat, c='blue', lw=4, label='regression line')
plt.xlabel('Head Size(cm^3) ', fontsize=15)
plt.ylabel('Brain Weight(grams)', fontsize=15)
plt.show()

# %% [markdown]
# ### let us try to predict the brain size

# %%
new_data = pd.DataFrame({'const':1, 'Head Size(cm^3)': [4512]}) 
predicted_brain_size=results.predict(new_data)

# %%
predicted_brain_size
# Out:
# 0    1514.166601
# dtype: float64

# %% [markdown]
# ### this has come to an end of our prediction using simple linear regression
